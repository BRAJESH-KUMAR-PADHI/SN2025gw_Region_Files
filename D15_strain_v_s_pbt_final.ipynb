# %% [markdown]
# Plotting strain vs time for different regions

# %%
with open('/content/D15-3D_by_Zones_Zaxis.dat','r',encoding='utf-8') as f:
      content = f.read()
print(content)
# Out:
#  # The following quantities are given in cgs units, except post-bounce time that is in milliseconds
#  # post-bounce time, rh+ i,  rhx i [with i = 0 to 5], rh+ total, rhx total
#   0.20000000E+01  0.14981157E-02 -0.12768282E-04  0.26305914E-02 -0.25556032E-04  0.62112357E-01 -0.68878714E-03  0.21980077E-01 -0.11291282E-03  0.00000000E+00  0.00000000E+00 -0.31721514E-01  0.13356210E-01  0.54115050E-01  0.12536041E-01
#   0.22000000E+01  0.88302833E+00 -0.10946400E-01  0.50742424E+00 -0.64162542E-02 -0.34967171E+02  0.47275448E+00  0.27139484E+02 -0.38305688E+00  0.00000000E+00  0.00000000E+00  0.63996758E+01 -0.17791319E+00  0.52612498E-01 -0.10581648E+00
#   0.24000001E+01  0.95689785E+00 -0.13047796E-01  0.10433600E+01 -0.14116880E-01 -0.46474232E+02  0.64178038E+00  0.37935669E+02 -0.53926152E+00  0.00000000E+00  0.00000000E+00  0.65002365E+01 -0.18089575E+00  0.52186251E-01 -0.10607843E+00
# ...

# %%
import pandas as pd
with open('/content/D15-3D_by_Zones_Zaxis.dat','r') as f:
    lines = f.readlines()[2:]
data1=[[float(x) for x in line.split()]for line in lines]
df1 = pd.DataFrame(data1,columns=['pbt','rh+0','rhx0','rh+1','rhx1','rh+2','rhx2','rh+3','rhx3','rh+4','rhx4','rh+5','rhx5','rh+t','rhxt'])
print(df1.head())
# Out:
#    pbt      rh+0      rhx0      rh+1      rhx1       rh+2      rhx2  \
# 0  2.0  0.001498 -0.000013  0.002631 -0.000026   0.062112 -0.000689
# 1  2.2  0.883028 -0.010946  0.507424 -0.006416 -34.967171  0.472754
# 2  2.4  0.956898 -0.013048  1.043360 -0.014117 -46.474232  0.641780
# 3  2.6 -0.502355  0.005940 -0.634995  0.008748  -3.170661  0.045299
# 4  2.8 -0.156296  0.002291 -0.491083  0.005545  -1.293457  0.009123
#
#         rh+3      rhx3  rh+4  rhx4      rh+5      rhx5      rh+t      rhxt
# 0   0.021980 -0.000113   0.0   0.0 -0.031722  0.013356  0.054115  0.012536
# 1  27.139484 -0.383057   0.0   0.0  6.399676 -0.177913  0.052612 -0.105816
# 2  37.935669 -0.539262   0.0   0.0  6.500236 -0.180896  0.052186 -0.106078
# 3  -2.511814  0.022015   0.0   0.0  6.490426 -0.180435  0.051725 -0.106780
# 4  -5.036745  0.067288   0.0   0.0  6.796050 -0.186401  0.051798 -0.106131

# %%
pbt = df1['pbt'].to_numpy()
print(pbt)
# Out:
# [  2.          2.2         2.4000001 ... 741.        741.20001
#  741.40002  ]

# %% [markdown]
# # h+ plots

# %%
rhp0 = df1['rh+0'].to_numpy()
print(rhp0)
# Out:
# [ 0.00149812  0.88302833  0.95689785 ...  0.04240751 -0.14959267
#  -0.06098811]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))
plt.plot(pbt,rhp0,color='navy')
plt.xlim(left=100, right=740)
plt.xlabel("Postbounce Time(ms)", fontsize=8)
plt.ylabel("Strain(cgs)", fontsize=8)
plt.title("Strain plot for rh+0", fontsize=10)
plt.grid(True)
plt.show()

# %%
rhp1 = df1['rh+1'].to_numpy()
print(rhp1)
# Out:
# [ 0.00263059  0.50742424  1.04336    ... -0.15628944 -0.96078771
#   0.38252366]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))
plt.plot(pbt,rhp1,color='navy')
plt.xlim(left=100, right=740)
plt.xlabel("Postbounce Time(ms)", fontsize=8)
plt.ylabel("Strain(cgs)", fontsize=8)
plt.title("Strain plot for rh+1", fontsize=10)
plt.grid(True)
plt.show()

# %%
rhp2 = df1['rh+2'].to_numpy()
print(rhp2)
# Out:
# [  0.06211236 -34.967171   -46.474232   ...   0.23653284  -0.18724449
#    0.65318865]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))
plt.plot(pbt,rhp2,color='navy')
plt.xlim(left=100, right=740)
plt.ylim(bottom=(-2.5), top=2.5)
plt.xlabel("Postbounce Time(ms)", fontsize=8)
plt.ylabel("Strain(cgs)", fontsize=8)
plt.title("Strain plot for rh+2", fontsize=10)
plt.grid(True)
plt.show()

# %%
rhp3 = df1['rh+3'].to_numpy()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))
plt.plot(pbt,rhp3,color='navy')
plt.xlim(left=100, right=740)
plt.ylim(bottom=(-2.5), top=2.5)
plt.xlabel("Postbounce Time(ms)", fontsize=8)
plt.ylabel("Strain(cgs)", fontsize=8)
plt.title("Strain plot for rh+3", fontsize=10)
plt.grid(True)
plt.show()

# %%
rhp4 = df1['rh+4'].to_numpy()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))
plt.plot(pbt,rhp4,color='navy')
plt.xlim(left=100, right=740)
plt.ylim(bottom=(-2), top=2)
plt.xlabel("Postbounce Time(ms)", fontsize=8)
plt.ylabel("Strain(cgs)", fontsize=8)
plt.title("Strain plot for rh+4", fontsize=10)
plt.grid(True)
plt.show()

# %%
rhp5 = df1['rh+5'].to_numpy()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))
plt.plot(pbt,rhp5,color='navy')
plt.xlim(left=100, right=740)
plt.ylim((-2.5,2.5))
plt.xlabel("Postbounce Time(ms)", fontsize=8)
plt.ylabel("Strain(cgs)", fontsize=8)
plt.title("Strain plot for rh+5", fontsize=10)
plt.grid(True)
plt.show()

# %%
rhpt = df1['rh+t'].to_numpy()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))
plt.plot(pbt,rhpt,color='navy')
plt.xlim(left=100, right=740)
plt.xlabel("Postbounce Time(ms)", fontsize=8)
plt.ylabel("Strain(cgs)", fontsize=8)
plt.title("Strain plot for rh+t", fontsize=10)
plt.grid(True)
plt.show()

# %% [markdown]
# # hx plots

# %%
rhx0 = df1['rhx0'].to_numpy()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))
plt.plot(pbt,rhx0,color='orange')
plt.xlim(left=100, right=740)
plt.xlabel("Postbounce Time(ms)", fontsize=8)
plt.ylabel("Strain(cgs)", fontsize=8)
plt.title("Strain plot for rhx0", fontsize=10)
plt.grid(True)
plt.show()

# %%
rhx1 = df1['rhx1'].to_numpy()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))
plt.plot(pbt,rhx1,color='orange')
plt.xlim(left=100, right=740)
plt.xlabel("Postbounce Time(ms)", fontsize=8)
plt.ylabel("Strain(cgs)", fontsize=8)
plt.title("Strain plot for rhx1", fontsize=10)
plt.grid(True)
plt.show()

# %%
rhx2 = df1['rhx2'].to_numpy()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))
plt.plot(pbt,rhx2,color='orange')
plt.xlim(left=100, right=740)
plt.xlabel("Postbounce Time(ms)", fontsize=8)
plt.ylabel("Strain(cgs)", fontsize=8)
plt.title("Strain plot for rhx2", fontsize=10)
plt.grid(True)
plt.show()

# %%
rhx3 = df1['rhx3'].to_numpy()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))
plt.plot(pbt,rhx3,color='orange')
plt.xlim(left=100, right=740)
plt.xlabel("Postbounce Time(ms)", fontsize=8)
plt.ylabel("Strain(cgs)", fontsize=8)
plt.title("Strain plot for rhx3", fontsize=10)
plt.grid(True)
plt.show()

# %%
rhx4 = df1['rhx4'].to_numpy()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))
plt.plot(pbt,rhx4,color='orange')
plt.xlim(left=100, right=740)
plt.xlabel("Postbounce Time(ms)", fontsize=8)
plt.ylabel("Strain(cgs)", fontsize=8)
plt.title("Strain plot for rhx4", fontsize=10)
plt.grid(True)
plt.show()

# %%
rhx5 = df1['rhx5'].to_numpy()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))
plt.plot(pbt,rhx5,color='orange')
plt.xlim(left=100, right=740)
plt.xlabel("Postbounce Time(ms)", fontsize=8)
plt.ylabel("Strain(cgs)", fontsize=8)
plt.title("Strain plot for rhx5", fontsize=10)
plt.grid(True)
plt.show()

# %%
rhxt = df1['rhxt'].to_numpy()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))
plt.plot(pbt,rhxt,color='orange')
plt.xlim(left=100, right=740)
plt.xlabel("Postbounce Time(ms)", fontsize=8)
plt.ylabel("Strain(cgs)", fontsize=8)
plt.title("Strain plot for rhxt", fontsize=10)
plt.grid(True)
plt.show()

# %% [markdown]
# # **COLLECTIVE FIGURE(From 0ms)**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

fig,axs = plt.subplots(7, 2,figsize=(17, 10))
fig.suptitle("D15", fontsize=25)
plt.subplots_adjust(wspace=0, hspace=0)
for i,ax in enumerate(axs.flat):
    ax.grid(True)
    for spine in ax.spines.values():
      spine.set_visible(False)

    if i<12:
      ax.set_xticklabels([])
    else:
      ax.set_xlabel("Postbounce Time(ms)", fontsize=13)

axs[0,0].plot(pbt, rhp0, color='navy')
axs[0,0].set_xlim(left=0, right=740)
axs[0,0].set_ylabel("Rp0", fontsize=13,rotation=0,va='center')

axs[1,0].plot(pbt, rhp1, color='navy')
axs[1,0].set_xlim(left=0, right=740)
axs[1,0].set_ylabel("Rp1", fontsize=13,rotation=0,va='center')

axs[2,0].plot(pbt, rhp2, color='navy')
axs[2,0].set_xlim(left=0, right=740)
axs[2,0].set_ylabel("Rp2", fontsize=13,rotation=0,va='center')

axs[3,0].plot(pbt, rhp3, color='navy')
axs[3,0].set_xlim(left=0, right=740)
axs[3,0].set_ylabel("Rp3", fontsize=13,rotation=0,va='center')

axs[4,0].plot(pbt, rhp4, color='navy')
axs[4,0].set_xlim(left=0, right=740)
axs[4,0].set_ylabel("Rp4", fontsize=13,rotation=0,va='center')

axs[5,0].plot(pbt, rhp5, color='navy')
axs[5,0].set_xlim(left=0, right=740)
axs[5,0].set_ylabel("Rp5", fontsize=13,rotation=0,va='center')

axs[6,0].plot(pbt, rhpt, color='navy')
axs[6,0].set_xlim(left=0, right=740)
axs[6,0].set_ylabel("Total(p)", fontsize=13,rotation=0,va='center')

axs[0,1].plot(pbt, rhx0,color='orange')
axs[0,1].set_xlim(left=0, right=740)
axs[0,1].set_ylabel("Rx0", fontsize=13,rotation=0,va='center')


axs[1,1].plot(pbt, rhx1,color='orange')
axs[1,1].set_xlim(left=0, right=740)
axs[1,1].set_ylabel("Rx1", fontsize=13,rotation=0,va='center')


axs[2,1].plot(pbt, rhx2, color='orange')
axs[2,1].set_xlim(left=0, right=740)
axs[2,1].set_ylabel("Rx2", fontsize=13,rotation=0,va='center')


axs[3,1].plot(pbt, rhx3, color='orange')
axs[3,1].set_xlim(left=0, right=740)
axs[3,1].set_ylabel("Rx3", fontsize=13,rotation=0,va='center')


axs[4,1].plot(pbt, rhx4, color='orange')
axs[4,1].set_xlim(left=0, right=740)
axs[4,1].set_ylabel("Rx4", fontsize=13,rotation=0,va='center')


axs[5,1].plot(pbt, rhx5, color='orange')
axs[5,1].set_xlim(left=0, right=740)
axs[5,1].set_ylabel("Rx5", fontsize=13,rotation=0,va='center')


axs[6,1].plot(pbt, rhxt, color='orange')
axs[6,1].set_xlim(left=0, right=740)
axs[6,1].set_ylabel("Total(x)", fontsize=13,rotation=0,va='center')

plt.tight_layout()
plt.show()

# %% [markdown]
# # **COLLECTIVE FIGURE(From 100ms)**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

fig,axs = plt.subplots(7, 2,figsize=(17, 10))
fig.suptitle("D15", fontsize=25)
plt.subplots_adjust(wspace=0, hspace=0)
for i,ax in enumerate(axs.flat):
    ax.grid(True)
    for spine in ax.spines.values():
      spine.set_visible(False)

    if i<12:
      ax.set_xticklabels([])
    else:
      ax.set_xlabel("Postbounce Time(ms)", fontsize=13)

axs[0,0].plot(pbt, rhp0, color='navy')
axs[0,0].set_xlim(left=100, right=740)
axs[0,0].set_ylabel("Rp0", fontsize=13,rotation=0,va='center')

axs[1,0].plot(pbt, rhp1, color='navy')
axs[1,0].set_xlim(left=100, right=740)
axs[1,0].set_ylabel("Rp1", fontsize=13,rotation=0,va='center')

axs[2,0].plot(pbt, rhp2, color='navy')
axs[2,0].set_xlim(left=100, right=740)
axs[2,0].set_ylabel("Rp2", fontsize=13,rotation=0,va='center')

axs[3,0].plot(pbt, rhp3, color='navy')
axs[3,0].set_xlim(left=100, right=740)
axs[3,0].set_ylabel("Rp3", fontsize=13,rotation=0,va='center')

axs[4,0].plot(pbt, rhp4, color='navy')
axs[4,0].set_xlim(left=100, right=740)
axs[4,0].set_ylabel("Rp4", fontsize=13,rotation=0,va='center')

axs[5,0].plot(pbt, rhp5, color='navy')
axs[5,0].set_xlim(left=100, right=740)
axs[5,0].set_ylabel("Rp5", fontsize=13,rotation=0,va='center')

axs[6,0].plot(pbt, rhpt, color='navy')
axs[6,0].set_xlim(left=100, right=740)
axs[6,0].set_ylabel("Total(p)", fontsize=13,rotation=0,va='center')

axs[0,1].plot(pbt, rhx0,color='orange')
axs[0,1].set_xlim(left=100, right=740)
axs[0,1].set_ylabel("Rx0", fontsize=13,rotation=0,va='center')


axs[1,1].plot(pbt, rhx1,color='orange')
axs[1,1].set_xlim(left=100, right=740)
axs[1,1].set_ylabel("Rx1", fontsize=13,rotation=0,va='center')


axs[2,1].plot(pbt, rhx2, color='orange')
axs[2,1].set_xlim(left=100, right=740)
axs[2,1].set_ylabel("Rx2", fontsize=13,rotation=0,va='center')


axs[3,1].plot(pbt, rhx3, color='orange')
axs[3,1].set_xlim(left=100, right=740)
axs[3,1].set_ylabel("Rx3", fontsize=13,rotation=0,va='center')


axs[4,1].plot(pbt, rhx4, color='orange')
axs[4,1].set_xlim(left=100, right=740)
axs[4,1].set_ylabel("Rx4", fontsize=13,rotation=0,va='center')


axs[5,1].plot(pbt, rhx5, color='orange')
axs[5,1].set_xlim(left=100, right=740)
axs[5,1].set_ylabel("Rx5", fontsize=13,rotation=0,va='center')


axs[6,1].plot(pbt, rhxt, color='orange')
axs[6,1].set_xlim(left=100, right=740)
axs[6,1].set_ylabel("Total(x)", fontsize=13,rotation=0,va='center')

plt.tight_layout()
plt.show()

# %% [markdown]
# # **Combos**

# %%
rht = rhxt + rhpt
#OG
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))
plt.plot(pbt,rht,color='red')
plt.xlim(left=0, right=740)
plt.ylim((-8,8))
plt.xlabel("Postbounce Time(ms)", fontsize=8)
plt.ylabel("Strain(cgs)", fontsize=8)
plt.title("Strain plot for rht(0)", fontsize=10)
plt.grid(True)
plt.show()

# %%
rht = rhxt + rhpt
#Shifted
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))
plt.plot(pbt,rht,color='red')
plt.xlim(left=100, right=740)
plt.ylim((-8,8))
plt.xlabel("Postbounce Time(ms)", fontsize=8)
plt.ylabel("Strain(cgs)", fontsize=8)
plt.title("Strain plot for rht(100)", fontsize=10)
plt.grid(True)
plt.show()

# %%
rhs =  rhx5 + rhx4 + rhx3 + rhx2 + rhx1 + rhx0 + rhp5 + rhp4 + rhp3 + rhp2 + rhp1 + rhp0
#Explicite Sum
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))
plt.plot(pbt,rhs,color='red')
plt.xlim(left=0, right=740)
plt.ylim((-8,8))
plt.xlabel("Postbounce Time(ms)", fontsize=8)
plt.ylabel("Strain(cgs)", fontsize=8)
plt.title("Strain plot for rhs", fontsize=10)
plt.grid(True)
plt.show()

# %%
rhrem05 = rhx4 + rhx3 + rhx2 + rhx1 + rhp4 + rhp3 + rhp2 + rhp1
#R0,R5 removed
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))
plt.plot(pbt,rhrem05,color='red')
plt.xlim(left=100, right=740)
plt.ylim((-8,8))
plt.xlabel("Postbounce Time(ms)", fontsize=8)
plt.ylabel("Strain(cgs)", fontsize=8)
plt.title("Strain plot for rhrem05", fontsize=10)
plt.grid(True)
plt.show()

# %%
rh34 = rhx4 + rhx3 + rhp4 + rhp3
#only R3,R4 taken
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))
plt.plot(pbt,rh34,color='red')
plt.xlim(left=100, right=740)
plt.ylim((-8,8))
plt.xlabel("Postbounce Time(ms)", fontsize=8)
plt.ylabel("Strain(cgs)", fontsize=8)
plt.title("Strain plot for rh34", fontsize=10)
plt.grid(True)
plt.show()

# %%
rh12 = rhx2 + rhx1 + rhp2 + rhp1
#only R1,R2 taken
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))
plt.plot(pbt,rh12,color='red')
plt.xlim(left=100, right=740)
plt.ylim((-8,8))
plt.xlabel("Postbounce Time(ms)", fontsize=8)
plt.ylabel("Strain(cgs)", fontsize=8)
plt.title("Strain plot for rh12", fontsize=10)
plt.grid(True)
plt.show()

# %%
rh05 = rhx5 + rhx0 + rhp5 + rhp0
#only R0,R5 taken
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))
plt.plot(pbt,rh05,color='red')
plt.xlim(left=100, right=740)
plt.ylim((-8,8))
plt.xlabel("Postbounce Time(ms)", fontsize=8)
plt.ylabel("Strain(cgs)", fontsize=8)
plt.title("Strain plot for rh05", fontsize=10)
plt.grid(True)
plt.show()

# %%
rh12_100130 = rhx1 + rhx2 + rhp1 + rhp2
#100-130 ms, not much signal for R1,R2
rh34_100130 = rhp3 + rhp4 + rhx3 + rhx4
#100-130 ms, very less signal for R3,R4
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))
plt.plot(pbt,rh12_100130,color='red', label='R12')
plt.plot(pbt,rh34_100130,color='navy', label='R34')
plt.xlim(left=100, right=130)
plt.ylim((-8,8))
plt.xlabel("Postbounce Time(ms)", fontsize=8)
plt.ylabel("Strain(cgs)", fontsize=8)
plt.title("Strain plot for rh_100130", fontsize=10)
plt.grid(True)
plt.legend()
plt.show()

# %%
rh12_130160 = rhx1 + rhx2 + rhp1 + rhp2
rh34_130160 = rhp3 + rhp4 + rhx3 + rhx4
#100-130 ms, very low signal for R1,R2 but somewhat comparable to R3,R4
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))
plt.plot(pbt,rh12_130160,color='red', label='R12')
plt.plot(pbt,rh34_130160,color='navy', label='R34')
plt.xlim(left=130, right=160)
plt.ylim((-8,8))
plt.xlabel("Postbounce Time(ms)", fontsize=8)
plt.ylabel("Strain(cgs)", fontsize=8)
plt.title("Strain plot for rh_130160", fontsize=10)
plt.grid(True)
plt.savefig('rh_130160.png',dpi=400)
plt.legend()
plt.show()

# %%
rh12_160240 = rhx1 + rhx2 + rhp1 + rhp2
rh34_160240 = rhp3 + rhp4 + rhx3 + rhx4
#160-240 ms, appreciable signal for R1,R2 nearly equivalent to R3,R4
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))
plt.plot(pbt,rh12_160240,color='red', label='R12')
plt.plot(pbt,rh34_160240,color='navy', label='R34')
plt.xlim(left=160, right=240)
plt.ylim((-8,8))
plt.xlabel("Postbounce Time(ms)", fontsize=8)
plt.ylabel("Strain(cgs)", fontsize=8)
plt.title("Strain plot for rh_160240", fontsize=10)
plt.grid(True)
plt.savefig('rh_160240.png',dpi=400)
plt.legend()
plt.show()

# %%
rh12_240300 = rhx1 + rhx2 + rhp1 + rhp2
rh34_240300 = rhp3 + rhp4 + rhx3 + rhx4
#240-300 ms, high signal for R1,R2 larger than R3,R4
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))
plt.plot(pbt,rh12_240300,color='red', label='R12')
plt.plot(pbt,rh34_240300,color='navy', label='R34')
plt.xlim(left=240, right=300)
plt.ylim((-8,8))
plt.xlabel("Postbounce Time(ms)", fontsize=8)
plt.ylabel("Strain(cgs)", fontsize=8)
plt.title("Strain plot for rh_240300", fontsize=10)
plt.grid(True)
plt.savefig('rh_240300.png',dpi=400)
plt.legend()
plt.show()

# %%
rh12_300740 = rhx1 + rhx2 + rhp1 + rhp2
rh34_300740 = rhp3 + rhp4 + rhx3 + rhx4
#300-740 ms, very high signal for R1,R2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))
plt.plot(pbt,rh12_300740,color='red', label='R12')
plt.plot(pbt,rh34_300740,color='navy', label='R34')
plt.xlim(left=300, right=740)
plt.ylim((-8,8))
plt.xlabel("Postbounce Time(ms)", fontsize=8)
plt.ylabel("Strain(cgs)", fontsize=8)
plt.title("Strain plot for rh_300740", fontsize=10)
plt.grid(True)
plt.legend()
plt.show()

# %%
rh1 = rhx1 + rhp1
rh2 = rhx2 + rhp2
rh3 = rhx3 + rhp3
rh4 = rhx4 + rhp4
#100-130 ms, individual plots
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))
plt.plot(pbt,rh1,color='navy', label='R1')
plt.plot(pbt,rh2,color='green', label='R2')
plt.plot(pbt,rh3,color='orange', label='R3')
plt.plot(pbt,rh4,color='red', label='R4')
plt.xlim(left=100, right=130)
plt.ylim((-1,1))
plt.xlabel("Postbounce Time(ms)", fontsize=8)
plt.ylabel("Strain(cgs)", fontsize=8)
plt.title("Strain plot for rhi_100130", fontsize=10)
plt.grid(True)
plt.legend()
plt.show()

# %%
rh1 = rhx1 + rhp1
rh2 = rhx2 + rhp2
rh3 = rhx3 + rhp3
rh4 = rhx4 + rhp4
#130-160 ms, individual plots
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))
plt.plot(pbt,rh1,color='navy', label='R1')
plt.plot(pbt,rh2,color='green', label='R2')
plt.plot(pbt,rh3,color='orange', label='R3')
plt.plot(pbt,rh4,color='red', label='R4')
plt.xlim(left=130, right=160)
plt.ylim((-3,3))
plt.xlabel("Postbounce Time(ms)", fontsize=8)
plt.ylabel("Strain(cgs)", fontsize=8)
plt.title("Strain plot for rhi_130160", fontsize=10)
plt.grid(True)
plt.savefig('1234_130160.png',dpi=400)
plt.legend()
plt.show()

# %%
rh1 = rhx1 + rhp1
rh2 = rhx2 + rhp2
rh3 = rhx3 + rhp3
rh4 = rhx4 + rhp4
#160-240 ms, individual plots
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))
plt.plot(pbt,rh1,color='navy', label='R1')
plt.plot(pbt,rh2,color='green', label='R2')
plt.plot(pbt,rh3,color='orange', label='R3')
plt.plot(pbt,rh4,color='red', label='R4')
plt.xlim(left=160, right=240)
plt.ylim((-4,4))
plt.xlabel("Postbounce Time(ms)", fontsize=8)
plt.ylabel("Strain(cgs)", fontsize=8)
plt.title("Strain plot for rhi_160240", fontsize=10)
plt.grid(True)
plt.legend()
plt.show()

# %%
rh1 = rhx1 + rhp1
rh2 = rhx2 + rhp2
rh3 = rhx3 + rhp3
rh4 = rhx4 + rhp4
#240-300 ms, individual plots
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))
plt.plot(pbt,rh1,color='navy', label='R1')
plt.plot(pbt,rh2,color='green', label='R2')
plt.plot(pbt,rh3,color='orange', label='R3')
plt.plot(pbt,rh4,color='red', label='R4')
plt.xlim(left=240, right=300)
plt.ylim((-5,5))
plt.xlabel("Postbounce Time(ms)", fontsize=8)
plt.ylabel("Strain(cgs)", fontsize=8)
plt.title("Strain plot for rhi_240300", fontsize=10)
plt.grid(True)
plt.legend()
plt.show()

# %%
rh1 = rhx1 + rhp1
rh2 = rhx2 + rhp2
rh3 = rhx3 + rhp3
rh4 = rhx4 + rhp4
#300-740 ms, individual plots
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))
plt.plot(pbt,rh1,color='navy', label='R1')
plt.plot(pbt,rh2,color='green', label='R2')
plt.plot(pbt,rh3,color='orange', label='R3')
plt.plot(pbt,rh4,color='red', label='R4')
plt.xlim(left=300, right=740)
plt.ylim((-5,5))
plt.xlabel("Postbounce Time(ms)", fontsize=8)
plt.ylabel("Strain(cgs)", fontsize=8)
plt.title("Strain plot for rhi_300740", fontsize=10)
plt.grid(True)
plt.legend()
plt.show()

# %%
rh3 = rhx3 + rhp3
rh4 = rhx4 + rhp4
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))
plt.plot(pbt,rh3,color='orange', label='R3')
plt.plot(pbt,rh4,color='red', label='R4')
plt.xlim(left=150, right=190)
plt.ylim((-3,3))
plt.xlabel("Postbounce Time(ms)", fontsize=8)
plt.ylabel("Strain(cgs)", fontsize=8)
plt.title("Strain plot for phase", fontsize=10)
plt.grid(True)
plt.legend()
plt.show()

# %%
rh3 = rhx3 + rhp3
rh2 = rhx2 + rhp2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))
plt.plot(pbt,rh3,color='orange', label='R3')
plt.plot(pbt,rh2,color='green', label='R2')
plt.xlim(left=150, right=190)
plt.ylim((-3,3))
plt.xlabel("Postbounce Time(ms)", fontsize=8)
plt.ylabel("Strain(cgs)", fontsize=8)
plt.title("Strain plot for phase", fontsize=10)
plt.grid(True)
plt.legend()
plt.show()
